# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id     budget    revenue            original_title  \
# 818   tt0377981   36000000  189712432           Gnomeo & Juliet
# 202   tt2106361   50000000  160602194            Into the Storm
# 111   tt1243974   37000000   26250020                     Aloha
# 1036  tt1195478   30000000   53909751  The Five-Year Engagement
# 1313  tt0372784  150000000  374218673             Batman Begins
#
#                                                    cast           director  \
# 818   James McAvoy|Michael Caine|Maggie Smith|Julie ...       Kelly Asbury
# 202   Richard Armitage|Sarah Wayne Callies|Matt Wals...       Steven Quale
# 111   Bradley Cooper|Emma Stone|Rachel McAdams|John ...      Cameron Crowe
# 1036  Emily Blunt|Alison Brie|Jason Segel|Rhys Ifans...   Nicholas Stoller
# 1313  Christian Bale|Michael Caine|Liam Neeson|Katie...  Christopher Nolan
#
#                                                 tagline  \
# 818                 A little adventure goes a lawn way.
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок:
profit = data['revenue'] - data['budget']
data['profit'] = profit

def separation(x):
    a = str(x)
    b = a.split('|')
    return b

import itertools as it

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
answers['1'] = 'Pirates of the Caribbean: On Stranger Tides' #+

# %%
data[(data.budget == data.budget.max())]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year     profit
# 723           6.3          2011  641683000

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
answers['2'] = 'Gods and Generals' #+

# %%
data[(data.runtime == data.runtime.max())]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year    profit
# 1157           5.8          2003 -43076064

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = 'Winnie the Pooh' #+

# %%
data[(data.runtime == data.runtime.min())]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year    profit
# 768    4/13/2011           6.8          2011 -15540000

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '110' #+

# %%
data.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '107' #+

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year  \
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000
#
#              profit
# count  1.889000e+03
# mean   1.010545e+08
# std    1.830733e+08
# min   -1.657101e+08
# 25%    5.000000e+06
# 50%    4.400041e+07
# 75%    1.201842e+08
# max    2.544506e+09

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
answers['6'] = 'Avatar' #+

# %%
data[(data.profit == data.profit.max())]
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year      profit
# 239           7.1          2009  2544505847

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = 'The Lone Ranger' #+

# %%
data[(data.profit == data.profit.min())]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1478' #+

# %%
data[data.profit > 0].imdb_id.count()
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = 'The Dark Knight' #+

# %%
a = data[data.release_year == 2008].revenue.max() #assigning max revenue in 2008 to variable "a"
data[data.revenue == a] #displaying a series filtered by "a"
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = 'The Lone Ranger' #+

# %%
a = data[(data.release_year >= 2012) & (data.release_year <= 2014)].profit.min() #assigning min profit in 2012-2014 to "a"
data[data.profit == a] #displaying a series filtered by "a"
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
answers['11'] = 'Drama' #+

# %%
data11 = data.copy()

genres_splitted = data['genres'].apply(separation) #applying "separation" function to genres
data['genres'] = genres_splitted.explode('genres') #saving split genres in copy of initial dataframe and exploding genres into "one per line"
display(data.genres.value_counts()) #counting how many times each genre was mentioned in new dataframe
# Out:
# Drama              283
# Comedy             252
# Action             225
# Thriller           206
# Adventure          164
# Romance            122
# Science Fiction    109
# Crime              107
# Family              94
# Fantasy             84
# Mystery             66
# Horror              55
# Animation           49
# War                 25
# Music               22
# History             19
# Western              5
# Foreign              1
# Documentary          1
# Name: genres, dtype: int64

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = 'Drama' #+

# %%
data12 = data.copy()

genres_separated = data12['genres'].apply(separation)
data12['genres'] = genres_separated.explode('genres')
data12[data.profit > 0].genres.value_counts()
# Out:
# Drama              229
# Comedy             183
# Action             178
# Thriller           156
# Adventure          129
# Romance             94
# Science Fiction     89
# Crime               83
# Family              71
# Fantasy             70
# Mystery             51
# Horror              44
# Animation           39
# War                 22
# Music               17
# History             16
# Western              5
# Foreign              1
# Documentary          1
# Name: genres, dtype: int64

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = 'Peter Jackson' #+

# %%
data13 = data.copy()

director_separated = data13['director'].apply(separation)
data13['director'] = director_separated.explode('director')
grouppped_by_director = data.groupby([data.director]).sum()
grouppped_by_director.profit.sort_values()
# Out:
# director
# James L. Brooks              -96289726
# Ron Underwood                -92896027
# Peter Hyams                  -86956545
# David Bowers|Sam Fell        -84540684
# Walter Hill|Jack Sholder     -75171919
#                                ...
# Michael Bay                 2760938960
# J.J. Abrams                 2839169916
# Christopher Nolan           3162548502
# David Yates                 3379295625
# Peter Jackson               5202593685
# Name: profit, Length: 957, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = 'Robert Rodriguez' #+

# %%
data14 = data.copy()

action_only = data14[data14.genres.str.match('Action', na=False)].copy()
action_only['director'] = action_only['director'].apply(separation)
director_exploded = action_only.explode('director')

director_exploded.director.value_counts()
# Out:
# Nancy Meyers         3
# James McTeigue       3
# Steven Soderbergh    3
# Justin Lin           3
# Ridley Scott         3
#                     ..
# Charles Stone III    1
# Darren Aronofsky     1
# Sam Raimi            1
# Mennan Yapo          1
# Peter Farrelly       1
# Name: director, Length: 208, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = 'Chris Hemsworth' #+

# %%
data15 = data.copy()

year = data15[data15.release_year == 2012].sort_values('revenue')
year['cast'] = year['cast'].apply(separation)
cast_exploded = year.explode('cast')
summed_revenue = cast_exploded.groupby(['cast']).revenue.sum()
summed_revenue.sort_values()
# Out:
# cast
# Nicolas Cage            2106557
# Josh Lucas              2106557
# Sami Gayle              2106557
# Danny Huston            2106557
# Jason Bateman           3428048
#                         ...
# Robert Downey Jr.    1519557910
# Chris Evans          1519557910
# Anne Hathaway        1522851057
# Denis Leary          1629460639
# Chris Hemsworth      2027450773
# Name: revenue, Length: 466, dtype: int64

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = 'Matt Damon' #+

# %%
data16 = data.copy()

high_budget = data[data.budget > data.budget.mean()]
cast_splitted = high_budget['cast'].apply(separation)
cast_splitted.explode(True).value_counts()
# Out:
# Matt Damon             18
# Adam Sandler           17
# Angelina Jolie         16
# Tom Cruise             15
# Eddie Murphy           15
#                        ..
# Chris O'Dowd            1
# Spencer Treat Clark     1
# Rob Corddry             1
# Burt Reynolds           1
# David Burrows           1
# Name: cast, Length: 1505, dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = 'Action' #+

# %%
pd.Series(data[data.cast.str.contains('Nicolas Cage', na=False)].genres.str.split('|').sum()).value_counts()
# Out:
# Action       5
# Family       5
# Adventure    3
# Thriller     3
# Drama        3
# Comedy       2
# Mystery      2
# War          2
# Horror       1
# Crime        1
# dtype: int64

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = '' #-

# %%
production_companies_splitted = data['production_companies'].apply(separation)
data['production_companies_splitted'] = production_companies_splitted.explode('production_companies')

data[data.production_companies_splitted == 'Paramount Pictures'].profit.sort_values()
# Out:
# 1853     -44187007
# 1845     -12616311
# 1544      -8594405
# 455       -5185211
# 1792       2217407
# 325        2357900
# 1266       3008161
# 582        3929123
# 446        4145613
# 263        6471023
# 1305      10179302
# 1754      12295611
# 308       12536299
# 842       12547440
# 817       33782078
# 1717      41122026
# 316       61000000
# 1703      61608995
# 874       65771527
# 384       66952305
# 81        77597242
# 84        93450062
# 1142     104433867
# 24       105346506
# 793      107817248
# 1372     125216468
# 1469     133262620
# 614      137231186
# 1324     245176741
# 586      264692268
# 1802     339632142
# 1682     357610419
# 1081    1024888979
# Name: profit, dtype: int64

# %%
data[data.profit == -64831034]
# Out:
#        imdb_id     budget   revenue        original_title  \
# 925  tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 925  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 925  Fate has found its hero.
#
#                                               overview  runtime    genres  \
# 925  When Russia's first nuclear submarine malfunct...      138  Thriller
#
#                                   production_companies release_date  \
# 925  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_average  release_year    profit production_companies_splitted
# 925           6.0          2002 -64831034                 Radical Media

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '2015' #+

# %%
data19 = data.copy()

a = data19.groupby([data19.release_year]).revenue.sum()
a.sort_values()
# Out:
# release_year
# 2000    10664099805
# 2001    13017764865
# 2002    14136361487
# 2003    14346123312
# 2006    14775042320
# 2005    15309425558
# 2004    15663430720
# 2007    18162406801
# 2008    18252781990
# 2009    20261791024
# 2010    21071204961
# 2011    22676791872
# 2012    23079001687
# 2013    23213799791
# 2014    23405862953
# 2015    25449202382
# Name: revenue, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '2014' #+

# %%
production_companies_splitted = data['production_companies'].apply(separation)
data['production_companies'] = production_companies_splitted.explode('production_companies')

bu = data[data.production_companies == 'Warner Bros.']
su = bu.groupby(['release_year']).sum()
su.profit.sort_values()
# Out:
# release_year
# 2012     24910702
# 2002     50361625
# 2003     60259536
# 2008     75388063
# 2000    113292716
# 2004    120852608
# 2009    125605724
# 2013    184629136
# 2015    194694182
# 2006    222516247
# 2010    404763806
# 2007    519284657
# 2011    624688502
# 2005    733456367
# 2001    921499139
# 2014    945442714
# Name: profit, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = 'Сентябрь' #+

# %%
import re 
data = pd.read_csv('movie_bd_v5.csv')

new_column = []
pattern = re.compile('\d*')

for item in data['release_date']:
    new_column.append(pattern.match(item).group(0))

months = pd.Series(new_column).value_counts()
display(months)
# Out:
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# dtype: int64

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '450' #+

# %%
147 + 142 + 161 #taking values from the previous task, sorry for that...
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = 'Peter Jackson' #+

# %%
data['month'] = new_column #new_column is taken from task 21
winter = data.query('month in ["12","1", "2"]')
winter.director.value_counts()
# Out:
# Peter Jackson                     7
# Clint Eastwood                    6
# Steven Soderbergh                 6
# Martin Scorsese                   4
# Adam Shankman                     4
#                                  ..
# Eric Bress|J. Mackye Gruber       1
# Alejandro GonzÃ¡lez IÃ±Ã¡rritu    1
# Antoine Fuqua                     1
# Kevin Allen                       1
# Robert Zemeckis                   1
# Name: director, Length: 332, dtype: int64

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = 'Four By Two Productions' #+

# %%
data = pd.read_csv('movie_bd_v5.csv')

data['production_companies'] = data.production_companies.apply(lambda x:x.split('|'))
data['title_len'] = data['original_title'].apply(lambda x: len(x))
data.title_len.sort_values()
# Out:
# 252      1
# 1282     2
# 643      2
# 714      2
# 243      2
#         ..
# 385     56
# 1751    58
# 219     59
# 1314    62
# 1448    83
# Name: title_len, Length: 1889, dtype: int64

# %%
data.loc[1448]
# Out:
# imdb_id                                                         tt0443453
# budget                                                           18000000
# revenue                                                         261572744
# original_title          Borat: Cultural Learnings of America for Make ...
# cast                    Sacha Baron Cohen|Ken Davitian|Luenell|Pamela ...
# director                                                    Larry Charles
# tagline                                    Come to Kazakhstan, it's nice!
# overview                Kazakh journalist Borat Sagdiyev travels to Am...
# runtime                                                                82
# genres                                                             Comedy
# production_companies    [Twentieth Century Fox Film Corporation, Four ...
# release_date                                                    11/2/2006
# vote_average                                                          6.4
# ...

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = 'Midnight Picture Show' #+

# %%
data = pd.read_csv('movie_bd_v5.csv')

data['overview_len'] = data['overview'].apply(lambda x: len(x))
companies = data.groupby(['production_companies'])['overview_len'].mean().sort_values()
display(companies)
# Out:
# production_companies
# Paramount Pictures|Plan B Entertainment|Regency Enterprises                                                         58.0
# Motion Picture Corporation of America|Artisan Entertainment                                                         59.0
# Cheyenne Enterprises|Epsilon Motion Pictures|Empire Pictures|Metro-Goldwyn-Mayer (MGM)|Hyde Park Entertainment      62.0
# Columbia Pictures Corporation|Apatow Productions                                                                    64.0
# Focus Films                                                                                                         72.0
#                                                                                                                    ...
# Lions Gate Family Entertainment|Relativity Media|Crest Animation Productions                                       909.0
# ...

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = 'Inside Out, The Dark Knight, 12 Years a Slave' #+

# %%
data = pd.read_csv('movie_bd_v5.csv')

vote_average_percentile = np.percentile(data['vote_average'], 99)

vote_average_percentile
# Out:
# 7.8

# %%
vote_average_data = data[data['vote_average'] > vote_average_percentile]
display(vote_average_data)
# Out:
#         imdb_id     budget     revenue  \
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 118   tt0816692  165000000   621752480
# 119   tt2015381  170000000   773312399
# 125   tt2084970   14000000   233555708
# 128   tt2267998   61000000   369330363
# 138   tt2278388   30000000   174600318
# 370   tt1375666  160000000   825500000
# 599   tt0468569  185000000  1001921825
# 872   tt0253474   35000000   120072577
# 1081  tt0167260   94000000  1118888979
# 1183  tt0993846  100000000   392000694
# 1191  tt2024544   20000000   187000000
# 1800  tt0209144    9000000    39723096
#
#                                      original_title  \
# 9                                        Inside Out
# 34                                             Room
# 118                                    Interstellar
# 119                         Guardians of the Galaxy
# 125                              The Imitation Game
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
answers['27'] = 'Daniel Radcliffe & Rupert Grint'

# %%
data = pd.read_csv('movie_bd_v5.csv')
cast = []
for item in data.cast:
    data_cast = item.split('|')
    cast.extend(list(it.combinations(data_cast,2)))
pd.Series(cast).value_counts()
# Out:
# (Daniel Radcliffe, Emma Watson)        8
# (Daniel Radcliffe, Rupert Grint)       8
# (Rupert Grint, Emma Watson)            7
# (Ben Stiller, Owen Wilson)             6
# (Johnny Depp, Helena Bonham Carter)    6
#                                       ..
# (Diane Keaton, Frances McDormand)      1
# (Craig Bierko, Bill Pullman)           1
# (Dominic West, Colin Salmon)           1
# (Frances McDormand, Eve Hewson)        1
# (Vin Diesel, Marton Csokas)            1
# Length: 18121, dtype: int64

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': 'Pirates of the Caribbean: On Stranger Tides',
#  '2': 'Gods and Generals',
#  '3': 'Winnie the Pooh',
#  '4': '110',
#  '5': '107',
#  '6': 'Avatar',
#  '7': 'The Lone Ranger',
#  '8': '1478',
#  '9': 'The Dark Knight',
#  '10': 'The Lone Ranger',
#  '11': 'Drama',
#  '12': 'Drama',
#  '13': 'Peter Jackson',
#  '14': 'Robert Rodriguez',
#  '15': 'Chris Hemsworth',
#  '16': 'Matt Damon',
#  '17': 'Action',
#  '18': '',
#  '19': '2015',
#  '20': '2014',
#  '21': 'Сентябрь',
#  '22': '450',
#  '23': 'Peter Jackson',
#  '24': 'Four By Two Productions',
#  '25': 'Midnight Picture Show',
#  '26': 'Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': 'Daniel Radcliffe & Rupert Grint'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
